# %% [markdown]
# # Working with Imperfect Data

# %% [markdown]
# ### This data set concerns building permits for demolition issued in the past five years or currently in progress
#
# ### Attributes:
#
# 1. **Application/Permit Number:** *The tracking number used to refer to this application or permit record in various Seattle DCI tracking systems.*
# 2. **Permit Type:** *Type of activity covered by the permit.*
# 3. **Address:** *Street address of the work site.*
# 4. **Description:** *Brief description of the work that will be done under this permit. This is subject to change prior to issuance of the permit, but generally more stable if an issue date exists. Very long descriptions have been truncated.*
# 5. **Category:** *The broad category of use or occupancy for the building where work is proposed. Valid choices are Commercial, Industrial, Institutional, Multifamily, and Single Family/Duplex. Mixed use structures are generally represented as Commercial.*
# 6. **Action Type:** *Subclassification for type of work being proposed. Valid choices will vary depending on the permit type.*
# 7. **Work Type:** *An indicator of the complexity of the project proposed. Easier projects can be issued without plan review; more complex projects generally require plan submittal and review.*
# 8. **Value:** *The value of the work being proposed based on fair market value (parts plus labor). The value displayed (if any) represents the best available information to date, and is subject to change if the project is modified. Value is not collected for all permit types.*
# 9. **Applicant Name:** *The name of the person or company listed on the application as the “primary applicant”. This may be the property owner, contractor, design professional, or other type of agent.*
# 10. **Application Date:** *The date the application was accepted as a complete submittal. If no Application Date exists this generally means the application is in a very early stage.*
# 11. **Issue Date:** *The date the application was issued as a valid permit. If an Application Date exists but no Issue Date exists, this generally means the application is still under review.*
# 12. **Final Date:** *The date the permit had all its inspections completed. If an Issue Date exists but no Final Date exists, this generally means the permit is still under inspection.*
# 13. **Expiration Date:** *The date the application is due to expire. Generally, this is the date by which work is supposed to be completed (baring renewals or further extensions). If no Expiration Date exists, this generally means the application is has not been issued yet.*
# 14. **Status:**	*The current status in the application/review/inspection lifecycle. Indicates the last process step that was fully completed.*
# 15. **Permit and Complaint Status URL:** *Link to view full details and current status information about this permit at Seattle DCI's website.*
# 16. **Latitude:** *Latitude of the worksite where permit activity occurs. May be missing for a small number of permits considered "Unaddressable"*
# 17. **Longitude:** *Longitude of the worksite where permit activity occurs. May be missing for a small number of permits considered "Unaddressable"*
# 18. **Location:** *Mapping coordinates for the permit address.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
demolition_data = pd.read_csv("../seattle-demolition.csv", sep=",")

# %% [markdown]
# *This data set has a lot of columns and is quite large. There are a few columns we are not interested in, for example we know that this data set is filtered so all the permit type and action type are going to be demolition.
# We are also not interested in latitute and longitude and location as we will focus on the address field.
# Lastly, we don't need the permit and complaint Status Url as it doesn't concern us at the moment.*

# %%
cleaner_demolition_data = pd.DataFrame(demolition_data,
                                       columns = [
                                           "Application/Permit Number",
                                           "Address",
                                           "Description",
                                           "Category",
                                           "Work Type",
                                           "Value",
                                           "Applicant Name",
                                           "Application Date",
                                           "Issue Date",
                                           "Final Date",
                                           "Expiration Date",
                                           "Status",
                                       ])

# %%
cleaner_demolition_data
# Out:
#       Application/Permit Number                Address  \
# 0                       6578443    1908 NOB HILL AVE N
# 1                       6578362         2636 1ST AVE N
# 2                       6578484     4027 LATONA AVE NE
# 3                       6578123     4311 SW BRANDON ST
# 4                       6578249       3909 E HOWELL ST
# 5                       6565362   6955 DELRIDGE WAY SW
# 6                       6577721        3935 2ND AVE NE
# 7                       6577047    6016 SW ADMIRAL WAY
# 8                       6577046       3046 61ST AVE SW
# 9                       6578106       3044 38TH AVE SW
# 10                      6577045       3050 61ST AVE SW
# 11                      6577979      10335 38TH AVE NE
# 12                      6577873       7033 14TH AVE NW
# 13                      6577806        1617 38TH AVE E
# 14                      6564131         719 24TH AVE S
# 15                      6577686        2315 42ND AVE E
# 16                      6564773        1617 38TH AVE E
# 17                      6577558       7337 44TH AVE SW
# 18                      6577497       2430 BOYER AVE E
# 19                      6577116       7516 30TH AVE NW
# 20                      6577508       4532 42ND AVE SW
# 21                      6535428        1532 15TH AVE E
# 22                      6573983    2303 FRANKLIN AVE E
# 23                      6577302        3001 NE 89TH ST
# 24                      6577226       8245 20TH AVE NE
# 25                      6577274   6530 DELRIDGE WAY SW
# 26                      6576950        1764 18TH AVE S
# 27                      6527794      2014 FAIRVIEW AVE
# 28                      6576696         2110 2ND AVE N
# 29                      6574121        9899 40TH AVE S
# ...                         ...                    ...
# 4235                    6549530        4728 30TH AVE S
# 4236                    6406682       1909 41ST AVE SW
# 4237                    6489535      2138 DEXTER AVE N
# 4238                    6121146         1619 S LANE ST
# 4239                    6308748    2215 BOYLSTON AVE E
# 4240                    6423925      10015 MARY AVE NW
# 4241                    6426792        1101 MADISON ST
# 4242                    6461218        3816 23RD AVE W
# 4243                    6341811         852 NE 89TH ST
# 4244                    6564281         1300 E PIKE ST
# 4245                    6329844       8424 20TH AVE SW
# 4246                    6317406       3621 S GRAHAM ST
# 4247                    6425178  3212 W GOVERNMENT WAY
# 4248                    6391892        5409 OHIO AVE S
# 4249                    6096402      12018 15TH AVE NE
# 4250                    6211518       7036 25TH AVE NW
# 4251                    6253854       4519 S KENYON ST
# 4252                    6564544       8512 11TH AVE NW
# 4253                    6418643        3629 35TH AVE W
# 4254                    6274564     2358 S ANGELINE ST
# 4255                    6431097      3835 GILMAN AVE W
# 4256                    6536587        3054 20TH AVE S
# 4257                    6559243      6650 CORSON AVE S
# 4258                    6471945         2400 6TH AVE S
# 4259                    6380911       1213 E SHELBY ST
# 4260                    6440299         2418 6TH AVE W
# 4261                    6397666       4535 44TH AVE SW
# 4262                    6553329         2022 S MAIN ST
# 4263                    6550250        1201 AMGEN CT W
# 4264                    6465077           1012 1ST AVE
#
#                                             Description  \
# 0     Demolish existing single family residence, sub...
# 1     Demolish existing SFR per (STFI) Subject to Fi...
# 2     Demolish Existing duplex to construct new SFR ...
# 3     Demo existing single family home, subject to f...
# 4     Demolish existing single family residence for ...
# 5     Demolish apartment building, foundation to rem...
# 6     Demolish existing single family residence, sub...
# 7     Demolish existing duplex, subject to field ins...
# 8     Demolish existing duplex, subject to field ins...
# 9     Demolition of single famaily residence and ass...
# 10    Demolish existing duplex, subject to field ins...
# 11    Demolish existing single family residence. Sub...
# 12    STFI*SUbject to field inspection demolish exii...
# 13    Demolish North portable classroom structure, p...
# 14    Demolish existing structure, subject to field ...
# 15    Demo single family residence/structure, per pl...
# 16    Demolish South portable classroom structure, p...
# 17    Demolish existing SFR, subject to field inspec...
# 18    Demolish existing Single Family Residence, Sub...
# 19    Demolish single family dwelling to top of foun...
# 20    STFI*SUbject to Field Inspection demolish exis...
# 21    Demolish existing single family residence (inc...
# 22    Demolish existing tri-plex per Subject to Fiel...
# 23    Demolish existing single family residence, exi...
# 24    Demolish existing structure, subject to field ...
# 25    Demo existing single family residence, subject...
# 26    STFI**Subject to field inspection demolish exi...
# 27     Demolish existing commercial building, per plan.
# 28    Demolish portion of existing single family res...
# 29    Demolish existing commercial building, slab on...
# ...                                                 ...
# 4235  Demo existing SFR, subject to field inspection...
# 4236  Demo existing single family house and shed (ST...
# 4237  Demolish single family residence and detached ...
# 4238  FD 3/22/10.BUILDING APPLICATION EXPIRED. PROJE...
# 4239                                  Demo existing SFR
# 4240  Establish use as and construct new single fami...
# 4241  2/24/2010 VJW: ADMINISTRATIVE PERMIT FOR TRACK...
# 4242  Demo existing single family home. Subject to F...
# 4243  Demolish existing single family residence (852...
# 4244  Demolish existing commercial structure, subjec...
# 4245                                         TEMP POWER
# 4246  Demolish existing single family residence with...
# 4247  Demo existing single family residence (STFI), ...
# 4248  Demolish existing office building, shop buildi...
# 4249  LFD 4/21/2010 PROJECT CANCELLED APPLICATION TO...
# 4250  LFD 4/19/2011 PROJECT CANCELLED REFER TO LOG 1...
# 4251  Demolish existing single family residence for ...
# 4252  Demo single family residence, per plan. Subjec...
# 4253  Demolition of existing structure, per subject ...
# 4254  LFD LTR SENT 5/21/13 LFD 8/14/13 PROJECT CANCE...
# 4255  Demolish existing single family dwelling and g...
# 4256  Demolish existing single family dwelling per s...
# 4257                  Demolish existing structure. STFI
# 4258  Demolish a portion of existing building, per p...
# 4259  Demolish existing one story 1074sf floating ho...
# 4260  Demo and Establish use and construct single fa...
# 4261                 Demolition existing structure STFI
# 4262  Demolish existing single family residence, sub...
# 4263  8/19/16 - CANCELLED CUSTOMER LOG #16-1270\nInt...
# 4264  Interior, non-structural demolition within an ...
#
#                     Category       Work Type  Value  \
# 0     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 1     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 2     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 3                 COMMERCIAL  No plan review  $0.00
# 4     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 5                MULTIFAMILY     Plan Review  $0.00
# 6                MULTIFAMILY  No plan review  $0.00
# 7     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 8     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 9     SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 10    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 11    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 12    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 13             INSTITUTIONAL     Plan Review  $0.00
# 14    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 15    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 16             INSTITUTIONAL     Plan Review  $0.00
# 17    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 18               MULTIFAMILY  No plan review  $0.00
# 19    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 20               MULTIFAMILY  No plan review  $0.00
# 21               MULTIFAMILY  No plan review  $0.00
# 22               MULTIFAMILY  No plan review  $0.00
# 23    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 24    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 25    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 26    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 27                COMMERCIAL     Plan Review  $0.00
# 28    SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 29                INDUSTRIAL  No plan review  $0.00
# ...                      ...             ...    ...
# 4235  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4236  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4237             MULTIFAMILY  No plan review  $0.00
# 4238  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4239             MULTIFAMILY  No plan review  $0.00
# 4240  SINGLE FAMILY / DUPLEX     Plan Review  $0.00
# 4241           INSTITUTIONAL  No plan review  $0.00
# 4242             MULTIFAMILY  No plan review  $0.00
# 4243             MULTIFAMILY  No plan review  $0.00
# 4244              COMMERCIAL  No plan review  $0.00
# 4245  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4246  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4247             MULTIFAMILY  No plan review  $0.00
# 4248              INDUSTRIAL     Plan Review  $0.00
# 4249             MULTIFAMILY  No plan review  $0.00
# 4250  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4251  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4252  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4253  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4254  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4255             MULTIFAMILY  No plan review  $0.00
# 4256  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4257  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4258              INDUSTRIAL  No plan review  $0.00
# 4259  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4260  SINGLE FAMILY / DUPLEX     Plan Review  $0.00
# 4261             MULTIFAMILY  No plan review  $0.00
# 4262  SINGLE FAMILY / DUPLEX  No plan review  $0.00
# 4263              COMMERCIAL     Plan Review  $0.00
# 4264              COMMERCIAL     Plan Review  $0.00
#
#                    Applicant Name Application Date  Issue Date  Final Date  \
# 0              CHRISTIANSON, KIRK       01/30/2017         NaN         NaN
# 1                    BIDDLE, DAVE       01/30/2017         NaN         NaN
# 2                    BIDDLE, DAVE       01/27/2017         NaN         NaN
# 3              KENNAN-MEYER, LISA       01/27/2017         NaN         NaN
# 4                   ELLIS, CAMPIE       01/27/2017         NaN         NaN
# 5                 SIMONSON, WENDY       01/26/2017         NaN         NaN
# 6                LEMONS, JONATHAN       01/26/2017         NaN         NaN
# 7                   NOVION, SHAUN       01/26/2017         NaN         NaN
# 8                   NOVION, SHAUN       01/26/2017         NaN         NaN
# 9                    DOTY, DWIGHT       01/26/2017         NaN         NaN
# 10                  NOVION, SHAUN       01/26/2017         NaN         NaN
# 11            KEYSER, CHRISTOPHER       01/26/2017         NaN         NaN
# 12                  WILLIAMS, NIK       01/25/2017         NaN         NaN
# 13               VANDERHORST, AMY       01/25/2017         NaN         NaN
# 14                    CARTER, TIM       01/25/2017         NaN         NaN
# 15              BELLISSIMO, BRYAN       01/25/2017         NaN         NaN
# 16               VANDERHORST, AMY       01/25/2017         NaN         NaN
# 17                   SAM, SAROEUN       01/24/2017         NaN         NaN
# 18               LEMONS, JONATHAN       01/23/2017         NaN         NaN
# 19                   WILBUR, JOEL       01/24/2017         NaN         NaN
# 20                 BARNES, BRENDA       01/23/2017         NaN         NaN
# 21                 HUMBLE, ROBERT       01/23/2017  01/23/2017         NaN
# 22            DIEPENBROCK, JEROME       01/20/2017         NaN         NaN
# 23                 DUMMER, ISAIAH       01/20/2017  01/20/2017         NaN
# 24                   BIDDLE, DAVE       01/20/2017         NaN         NaN
# 25                     LAVI, FRED       01/20/2017  01/20/2017         NaN
# 26                  WEBER, JULIAN       01/20/2017         NaN         NaN
# 27                    O'HARE, JON       01/20/2017         NaN         NaN
# 28                    ZHANG, MOON       01/20/2017         NaN         NaN
# 29    KIMURA, HOWARD AND FLORENCE       01/20/2017  01/20/2017         NaN
# ...                           ...              ...         ...         ...
# 4235               TAYLOR, DANIEL       08/10/2016  12/17/2016  02/01/2017
# 4236             WHOOLERY, AKASHA       03/03/2014  08/20/2014  09/08/2014
# 4237                WEBER, JULIAN       08/13/2015  02/19/2016         NaN
# 4238           OSTROVSKI, YEVGENI       10/28/2007         NaN         NaN
# 4239                RADIM BLAZEJ,       01/25/2012  03/22/2012  03/01/2013
# 4240                    KIRK, LEE              NaN         NaN         NaN
# 4241    HCP 1101 MADISON MOB LLC,              NaN         NaN         NaN
# 4242                FOSTER, DAVID       03/02/2015  10/21/2015         NaN
# 4243                    WICK, DAN       11/08/2012  04/11/2013  07/16/2015
# 4244                 SWAIN, AARON       12/21/2016         NaN         NaN
# 4245           D & K ELECTRIC INC              NaN         NaN         NaN
# 4246  KENS BULLDOZING & EXCATION,       04/18/2012  04/18/2012  04/27/2012
# 4247              KHOURI, BRADLEY       07/03/2014  12/30/2014  02/25/2015
# 4248             OBRYANT, MICHAEL              NaN         NaN         NaN
# 4249              PADILLA, MARTIN       01/06/2007         NaN         NaN
# 4250           CHRISTIANSON, KIRK       03/23/2009         NaN         NaN
# 4251              TSE ARCHITECTS,       11/17/2010         NaN         NaN
# 4252              KATSAROS, ESTER       10/31/2016  12/08/2016  02/01/2017
# 4253               CLOWARD, BRIAN       05/20/2014  02/04/2015  03/08/2016
# 4254              TSE ARCHITECTS,       02/14/2011         NaN         NaN
# 4255                NOVION, SHAUN       08/11/2014  02/01/2017         NaN
# 4256                  HEALEY, RON       05/24/2016  11/18/2016  02/01/2017
# 4257            MULLER, GABRIELLE       09/29/2016  02/01/2017         NaN
# 4258                CONWAY, BRETT       05/12/2015  05/22/2015  11/03/2015
# 4259               HOGEBOOM, ERIC       08/29/2013  12/31/2013  10/08/2014
# 4260                SQUIRES, GREG       10/14/2014  03/02/2015  12/15/2015
# 4261           MCCUNNEY, COURTNEY       08/18/2014  08/18/2014  02/19/2016
# 4262              MCVICARS, KATIE       08/29/2016  02/01/2017         NaN
# 4263       PATTERSON-O'HARE, JODI              NaN         NaN         NaN
# 4264       PATTERSON-O'HARE, JODI              NaN         NaN         NaN
#
#      Expiration Date                         Status
# 0                NaN              Reviews Completed
# 1                NaN              Reviews Completed
# 2                NaN              Reviews Completed
# 3                NaN              Reviews Completed
# 4                NaN              Reviews Completed
# 5                NaN           Application Accepted
# 6                NaN              Reviews Completed
# 7                NaN              Reviews Completed
# 8                NaN              Reviews Completed
# 9                NaN              Reviews Completed
# 10               NaN              Reviews Completed
# 11               NaN              Reviews Completed
# 12               NaN              Reviews Completed
# 13               NaN           Application Accepted
# 14               NaN              Reviews Completed
# 15               NaN              Reviews Completed
# 16               NaN           Application Accepted
# 17               NaN              Reviews Completed
# 18               NaN              Reviews Completed
# 19               NaN              Reviews Completed
# 20               NaN              Reviews Completed
# 21        07/23/2018                  Permit Issued
# 22               NaN              Reviews Completed
# 23        07/20/2018                  Permit Issued
# 24               NaN              Reviews Completed
# 25        07/20/2018                  Permit Issued
# 26               NaN              Reviews Completed
# 27               NaN           Application Accepted
# 28               NaN              Reviews Completed
# 29        07/20/2018                  Permit Issued
# ...              ...                            ...
# 4235      06/17/2018                  Permit Closed
# 4236      02/20/2016                  Permit Closed
# 4237      08/19/2017                  Permit Issued
# 4238             NaN              Reviews Completed
# 4239      09/22/2013                  Permit Closed
# 4240             NaN                            NaN
# 4241      08/24/2011                            NaN
# 4242      04/21/2017                  Permit Issued
# 4243      10/11/2014                  Permit Closed
# 4244             NaN              Reviews Completed
# 4245      06/11/2013                            NaN
# 4246      10/18/2013                  Permit Closed
# 4247      06/30/2016                  Permit Closed
# 4248             NaN  Initial Information Collected
# 4249             NaN              Reviews Completed
# 4250             NaN                      CANCELLED
# 4251             NaN              Reviews Completed
# 4252      06/08/2018                  Permit Closed
# 4253      08/04/2016                  Permit Closed
# 4254             NaN                      CANCELLED
# 4255      08/01/2018                  Permit Issued
# 4256      05/18/2018                  Permit Closed
# 4257      08/01/2018                  Permit Issued
# 4258      11/22/2016                  Permit Closed
# 4259      06/30/2015                  Permit Closed
# 4260      09/02/2016                  Permit Closed
# 4261      02/18/2016                  Permit Closed
# 4262      08/01/2018                  Permit Issued
# 4263             NaN                      CANCELLED
# 4264             NaN  Initial Information Collected
#
# [4265 rows x 12 columns]

# %% [markdown]
# ###  1. What is the proportion of single family house being demolished?

# %%
single_family = cleaner_demolition_data.loc[cleaner_demolition_data['Category'] == "SINGLE FAMILY / DUPLEX"]

# %%
prop_single_family = len(single_family) / len(cleaner_demolition_data) * 100

# %%
prop_single_family
# Out:
# 61.00820633059789

# %% [markdown]
# ### 2. What is the proportion of pending permits ?

# %%
pending_permit = cleaner_demolition_data.loc[cleaner_demolition_data["Status"] != "Permit Issued"]

# %% [markdown]
# *We effectively excluded all the permits with a status of permit issued. But we still have some permits that are not pending!*

# %%
pending_permit = pending_permit.loc[cleaner_demolition_data["Status"] != "Permit Closed"]

# %% [markdown]
# *Now we excluded the closed permits. We still need to account for the cancelled ones*

# %%
pending_permit = pending_permit.loc[cleaner_demolition_data["Status"] != "CANCELLED"]

# %%
len(pending_permit) / len(cleaner_demolition_data) * 100
# Out:
# 24.126611957796015

# %% [markdown]
# *The percentage of pending permits is about 24.13%*

# %% [markdown]
# ### 3. Who has the most applications pending ?

# %%
applicants_pending = pending_permit["Applicant Name"].value_counts()

# %%
applicants_pending
# Out:
# WEBER, JULIAN                50
# O'HARE, JON                  41
# PATTERSON-O'HARE, JODI       32
# NOVION, SHAUN                27
# KHOURI, BRADLEY              19
# ARD, BRITTANI                18
# BIDDLE, DAVE                 17
# LEMONS, JONATHAN             16
# HUMBLE, ROBERT               15
# SQUIRES, GREG                13
# NOVION, EINAR                12
# CHRISTIANSON, KIRK           11
# NOVION, ANDREW               11
# PIERCE, PAUL                 10
# SCHAEFFER, HUGH               9
# CARTER, TIM                   9
# PAROLINE, ANDY                8
# SPAAN, RANDALL                7
# DUFFUS, DAN                   7
# BRANT, GREG                   6
# JACKSON, MICHAEL              5
# SUSSEX, JAMES                 5
# TALLAR, PETER                 4
# LINARDIC, ED                  4
# DRISCOLL, MATT                4
# BARTHOLOMEW, TOM              4
# NEIMAN, DAVID                 4
# BULL, STEVE                   4
# WHOOLERY, AKASHA              4
# TRAN, BEN                     4
#                              ..
# GARY, BRIAN                   1
# O'MALLEY, BOB                 1
# BLAIS, JIMMY                  1
# FULTZ, CAMERON                1
# SWAIN, AARON                  1
# BEYERLEIN, TODD               1
# STEWART, LARRY                1
# AYRES, GARY                   1
# FAUST, GRANT                  1
# SCHROEDER, PETER              1
# KIRK, JOHN                    1
# PARKER, DEAN                  1
# HALE, ROBERT                  1
# POST, RICHARD                 1
# HALL, AYAKO                   1
# MONTGOMERY, MICHAEL           1
# THRONDSEN, LARRY              1
# KIM, BENNY                    1
# BENNETT, DAVID                1
# FINCH, ANDREW                 1
# PECK, RYAN                    1
# HCP 1101 MADISON MOB LLC,     1
# NEWELL, ROGER                 1
# DIEPENBROCK, JEROME           1
# KEYSER, CHRISTOPHER           1
# KELLY, ERIN                   1
# FANNING, THOMAS               1
# OJALA, VINCE                  1
# MANAGEMENT, GT                1
# HOBBS, KIMBERLY               1
# Name: Applicant Name, dtype: int64

# %% [markdown]
# ### 4. Who has the most applications ?

# %%
applicants = cleaner_demolition_data["Applicant Name"].value_counts()

# %%
applicants
# Out:
# WEBER, JULIAN                229
# BIDDLE, DAVE                 200
# PATTERSON-O'HARE, JODI       157
# NOVION, EINAR                107
# NOVION, SHAUN                101
# NOVION, ANDREW                85
# KHOURI, BRADLEY               80
# O'HARE, JON                   79
# LEDOUX, JULIE                 60
# PIERCE, PAUL                  55
# CHRISTIANSON, KIRK            49
# ARD, BRITTANI                 49
# SCHAEFFER, HUGH               49
# HUMBLE, ROBERT                47
# ZHANG, MOON                   41
# SQUIRES, GREG                 41
# WHOOLERY, AKASHA              38
# STRAIN, JESSICA               34
# STEPHENSON, RYAN              31
# COBB, PATRICK                 31
# KATSAROS, ESTER               30
# HAIZLIP, MARK                 30
# WEGENER, JEFF                 27
# BRANT, GREG                   25
# TALLAR, PETER                 24
# BELCHER, CRAIG                24
# WIERENGA, MARK                21
# LEMONS, JONATHAN              20
# DUFFUS, DAN                   20
# TRAN, BEN                     18
#                             ...
# DAVIS, STEVE                   1
# HALD, HELEN                    1
# PETERSON, CURT                 1
# HARRIS, BRIAN                  1
# EHRENBERG, RICK                1
# INGHAM, BRETT                  1
# JACOBSON, JOY                  1
# COSGROVE, JERRY                1
# HANEY, GERALD                  1
# HURI, ED                       1
# SCHILLER, STEVE                1
# GRANT, JENNIFER                1
# BREWER, SCOTT                  1
# HANEY, SEAN                    1
# APPLLEBY, KRISTA               1
# MARTIN, LEAH                   1
# LIN, PAUL                      1
# MARC, PEVOTO                   1
# STUMPF, LARRY                  1
# KUNASANGEAMPORN, JAN           1
# MCFARLAN, TOM                  1
# TREEN, LISA                    1
# STEVENSON, RYAN                1
# LINDNER, BONNIE                1
# ERICKSON, NEIL                 1
# BOONE, RENEE                   1
# BISHOP, RALPH @ KAREN LEE      1
# SEDERBERG, MARTIN              1
# LUSTER, JAMES                  1
# GEISSINGER, LAURIE             1
# Name: Applicant Name, dtype: int64

# %% [markdown]
# *H*
#
# *We can theorize applicants with several applications are contractors and applicants with one applications may be homeowners.*
#
# ### What is the proportion of single applications applicants vs multiple applications applicants?

# %%
total_single_application_applicants = 0
total_multiple_applications_applicants = 0

for i in applicants:
    if i == 1:
        total_single_application_applicants += 1
    else:
        total_multiple_applications_applicants += 1

# %%
print("multiple = " + str(total_multiple_applications_applicants/len(applicants)*100) + "%")
print("single = " + str(total_single_application_applicants/len(applicants) * 100) + "%")
# Out:
# multiple = 34.4275420336269%
# single = 65.5724579663731%
